# %%
# Turing Machine to calculate Fibonacci Sequence
# input = n
# output = F(n)

# %%
def parse(defn):
    states = {}
    for s in defn:
        state_name = s.split(":")[0]
        t_string = s.split(":")[1].strip().split(" ")
#         print(t_string)
#         assert (len(t_string) == 3)
        transition = {}
        for t in t_string:
            read = t[0]
            write = t[1]
            direction = t[2]
            next_state = t[3:]
            transition[read] = {"write": write, "direction": direction, "next":next_state}
        states[state_name] = transition
    return states

def run(machine, tape, debug=False):
    state = "START"
    head = 0
    head_char = None
    write = None
    while state != "HALT":
        head_char = tape[head]
        write = machine[state][head_char]["write"]
        tape[head] = write
        direction = machine[state][head_char]["direction"]
        next_state = machine[state][head_char]["next"]
        
        if debug == True:
            print_tape(tape, head)
            print("state ", state, "read", head_char, "write" , write)
            
        if direction == "R":
            head += 1
            if head >= len(tape):
                tape.append("_")
        else:
            head -= 1
            if head < 0:
                tape.insert(0,"_")
                head += 1
                
        state = next_state
        
    if debug == True:
        print_tape(tape, head)
        print("state ", state)
        
    return tape

def print_tape(tape, head):
    for i in range(0,head):
        print(tape[i], end="")
    print("^", end="")
    for i in range(head, len(tape)):
        print(tape[i], end="")
    print()

# %%
#Format: State number: (input<0,1,_>,output<0,1,_>,head<L,R>,newstate) x 3
#Machine: reads input, writes output to tape, moves in the direction specified
#Go to the end of the input
machine = [
    "START: 00RSTART 11RSTART __Rinit0",
    #write 00_01_ (we are using 00 to represent number 0 and 01 to represent 1 b/c we need to mark chars as read or not)
    "init0: 00Rinit1 10Rinit1 _0Rinit1",
    "init1: 00Rinit2 10Rinit2 _0Rinit2",
    "init2: 0_Rinit3 1_Rinit3 __Rinit3",
    "init3: 00Rinit4 10Rinit4 _0Rinit4",
    "init4: 01Rinit5 11Rinit5 _1Rinit5",
    "init5: 0_Lback0 1_Lback0 __Lback0", #moving L because we wrote a 1 already, so now we want to go back
    # tape now is "n_0*_1", go back to n
    "back0: 00Lback0 11Lback0 __Lback1",
    "back1: 00Lback1 11Lback1 __Lback2",
    "back2: 00Lback2 11Lback2 __Rcheckn0", #moving R because we were at a blank (to the left of n)
    #back at beginning, check to see if n == 0
    "checkn0: 00Rcheckn0 11Rsub0 __Rclean",
    # state 7 means n != 0
    # move to the right of n
    "sub0: 00Rsub0 11Rsub0 __Lsub1",
    # now at least significant bit of n, subtract 1
    "sub1: 01Lsub1 10Lsub2 __RHALT", # should never reach _
    "sub2: 00Lsub2 11Lsub2 __Rfib0",
    # state clean means n == 0  
    "clean: 00LHALT 11LHALT __LHALT",
    # state fib0 means we have to start adding the stuff (we are at leftmost bit of n)
    "fib0: 00Rfib0 11Rfib0 __Rfib1",
    "fib1: 00Rfib1 11Rfib1 __Rfib2", # at leftmost bit of the first number
    "fib2: 00Rfib2 11Rfib2 __Rfib3",
    "fib3: 00Rfib3 11Rfib3 _1Lfib4", # for now just keep on adding 1's to the end of the list (eventually do the sum)
    "fib4: 00Lfib4 11Lfib4 __Lback0", # we need to go back one extra "_" before going to the back subroutine
]

# %%
mach = parse(machine)
run(mach, tape = list("1011"), debug=True)
# Out:
# ^1011
# state  START read 1 write 1
# 1^011
# state  START read 0 write 0
# 10^11
# state  START read 1 write 1
# 101^1
# state  START read 1 write 1
# 1011^_
# state  START read _ write _
# 1011_^0
# state  init0 read _ write 0
# 1011_0^0
# state  init1 read _ write 0
# 1011_00^_
# state  init2 read _ write _
# 1011_00_^0
# state  init3 read _ write 0
# 1011_00_0^1
# state  init4 read _ write 1
# 1011_00_01^_
# state  init5 read _ write _
# 1011_00_0^1_
# state  back0 read 1 write 1
# 1011_00_^01_
# state  back0 read 0 write 0
# 1011_00^_01_
# state  back0 read _ write _
# 1011_0^0_01_
# state  back1 read 0 write 0
# 1011_^00_01_
# state  back1 read 0 write 0
# 1011^_00_01_
# state  back1 read _ write _
# 101^1_00_01_
# state  back2 read 1 write 1
# 10^11_00_01_
# state  back2 read 1 write 1
# 1^011_00_01_
# state  back2 read 0 write 0
# ^1011_00_01_
# state  back2 read 1 write 1
# ^_1011_00_01_
# state  back2 read _ write _
# _^1011_00_01_
# state  checkn0 read 1 write 1
# _1^011_00_01_
# state  sub0 read 0 write 0
# _10^11_00_01_
# state  sub0 read 1 write 1
# _101^1_00_01_
# state  sub0 read 1 write 1
# _1011^_00_01_
# state  sub0 read _ write _
# _101^0_00_01_
# state  sub1 read 1 write 0
# _10^10_00_01_
# state  sub2 read 1 write 1
# _1^010_00_01_
# state  sub2 read 0 write 0
# _^1010_00_01_
# state  sub2 read 1 write 1
# ^_1010_00_01_
# state  sub2 read _ write _
# _^1010_00_01_
# state  fib0 read 1 write 1
# _1^010_00_01_
# state  fib0 read 0 write 0
# _10^10_00_01_
# state  fib0 read 1 write 1
# _101^0_00_01_
# state  fib0 read 0 write 0
# _1010^_00_01_
# state  fib0 read _ write _
# _1010_^00_01_
# state  fib1 read 0 write 0
# _1010_0^0_01_
# state  fib1 read 0 write 0
# _1010_00^_01_
# state  fib1 read _ write _
# _1010_00_^01_
# state  fib2 read 0 write 0
# _1010_00_0^1_
# state  fib2 read 1 write 1
# _1010_00_01^_
# state  fib2 read _ write _
# _1010_00_01_^1
# state  fib3 read _ write 1
# _1010_00_01^_1
# state  fib4 read _ write _
# _1010_00_0^1_1
# state  back0 read 1 write 1
# _1010_00_^01_1
# state  back0 read 0 write 0
# _1010_00^_01_1
# state  back0 read _ write _
# _1010_0^0_01_1
# state  back1 read 0 write 0
# _1010_^00_01_1
# state  back1 read 0 write 0
# _1010^_00_01_1
# state  back1 read _ write _
# _101^0_00_01_1
# state  back2 read 0 write 0
# _10^10_00_01_1
# state  back2 read 1 write 1
# _1^010_00_01_1
# state  back2 read 0 write 0
# _^1010_00_01_1
# state  back2 read 1 write 1
# ^_1010_00_01_1
# state  back2 read _ write _
# _^1010_00_01_1
# state  checkn0 read 1 write 1
# _1^010_00_01_1
# state  sub0 read 0 write 0
# _10^10_00_01_1
# state  sub0 read 1 write 1
# _101^0_00_01_1
# state  sub0 read 0 write 0
# _1010^_00_01_1
# state  sub0 read _ write _
# _101^1_00_01_1
# state  sub1 read 0 write 1
# _10^01_00_01_1
# state  sub1 read 1 write 0
# _1^001_00_01_1
# state  sub2 read 0 write 0
# _^1001_00_01_1
# state  sub2 read 1 write 1
# ^_1001_00_01_1
# state  sub2 read _ write _
# _^1001_00_01_1
# state  fib0 read 1 write 1
# _1^001_00_01_1
# state  fib0 read 0 write 0
# _10^01_00_01_1
# state  fib0 read 0 write 0
# _100^1_00_01_1
# state  fib0 read 1 write 1
# _1001^_00_01_1
# state  fib0 read _ write _
# _1001_^00_01_1
# state  fib1 read 0 write 0
# _1001_0^0_01_1
# state  fib1 read 0 write 0
# _1001_00^_01_1
# state  fib1 read _ write _
# _1001_00_^01_1
# state  fib2 read 0 write 0
# _1001_00_0^1_1
# state  fib2 read 1 write 1
# _1001_00_01^_1
# state  fib2 read _ write _
# _1001_00_01_^1
# state  fib3 read 1 write 1
# _1001_00_01_1^1
# state  fib3 read _ write 1
# _1001_00_01_^11
# state  fib4 read 1 write 1
# _1001_00_01^_11
# state  fib4 read _ write _
# _1001_00_0^1_11
# state  back0 read 1 write 1
# _1001_00_^01_11
# state  back0 read 0 write 0
# _1001_00^_01_11
# state  back0 read _ write _
# _1001_0^0_01_11
# state  back1 read 0 write 0
# _1001_^00_01_11
# state  back1 read 0 write 0
# _1001^_00_01_11
# state  back1 read _ write _
# _100^1_00_01_11
# state  back2 read 1 write 1
# _10^01_00_01_11
# state  back2 read 0 write 0
# _1^001_00_01_11
# state  back2 read 0 write 0
# _^1001_00_01_11
# state  back2 read 1 write 1
# ^_1001_00_01_11
# state  back2 read _ write _
# _^1001_00_01_11
# state  checkn0 read 1 write 1
# _1^001_00_01_11
# state  sub0 read 0 write 0
# _10^01_00_01_11
# state  sub0 read 0 write 0
# _100^1_00_01_11
# state  sub0 read 1 write 1
# _1001^_00_01_11
# state  sub0 read _ write _
# _100^0_00_01_11
# state  sub1 read 1 write 0
# _10^00_00_01_11
# state  sub2 read 0 write 0
# _1^000_00_01_11
# state  sub2 read 0 write 0
# _^1000_00_01_11
# state  sub2 read 1 write 1
# ^_1000_00_01_11
# state  sub2 read _ write _
# _^1000_00_01_11
# state  fib0 read 1 write 1
# _1^000_00_01_11
# state  fib0 read 0 write 0
# _10^00_00_01_11
# state  fib0 read 0 write 0
# _100^0_00_01_11
# state  fib0 read 0 write 0
# _1000^_00_01_11
# state  fib0 read _ write _
# _1000_^00_01_11
# state  fib1 read 0 write 0
# _1000_0^0_01_11
# state  fib1 read 0 write 0
# _1000_00^_01_11
# state  fib1 read _ write _
# _1000_00_^01_11
# state  fib2 read 0 write 0
# _1000_00_0^1_11
# state  fib2 read 1 write 1
# _1000_00_01^_11
# state  fib2 read _ write _
# _1000_00_01_^11
# state  fib3 read 1 write 1
# _1000_00_01_1^1
# state  fib3 read 1 write 1
# _1000_00_01_11^1
# state  fib3 read _ write 1
# _1000_00_01_1^11
# state  fib4 read 1 write 1
# _1000_00_01_^111
# state  fib4 read 1 write 1
# _1000_00_01^_111
# state  fib4 read _ write _
# _1000_00_0^1_111
# state  back0 read 1 write 1
# _1000_00_^01_111
# state  back0 read 0 write 0
# _1000_00^_01_111
# state  back0 read _ write _
# _1000_0^0_01_111
# state  back1 read 0 write 0
# _1000_^00_01_111
# state  back1 read 0 write 0
# _1000^_00_01_111
# state  back1 read _ write _
# _100^0_00_01_111
# state  back2 read 0 write 0
# _10^00_00_01_111
# state  back2 read 0 write 0
# _1^000_00_01_111
# state  back2 read 0 write 0
# _^1000_00_01_111
# state  back2 read 1 write 1
# ^_1000_00_01_111
# state  back2 read _ write _
# _^1000_00_01_111
# state  checkn0 read 1 write 1
# _1^000_00_01_111
# state  sub0 read 0 write 0
# _10^00_00_01_111
# state  sub0 read 0 write 0
# _100^0_00_01_111
# state  sub0 read 0 write 0
# _1000^_00_01_111
# state  sub0 read _ write _
# _100^1_00_01_111
# state  sub1 read 0 write 1
# _10^11_00_01_111
# state  sub1 read 0 write 1
# _1^111_00_01_111
# state  sub1 read 0 write 1
# _^0111_00_01_111
# state  sub1 read 1 write 0
# ^_0111_00_01_111
# state  sub2 read _ write _
# _^0111_00_01_111
# state  fib0 read 0 write 0
# _0^111_00_01_111
# state  fib0 read 1 write 1
# _01^11_00_01_111
# state  fib0 read 1 write 1
# _011^1_00_01_111
# state  fib0 read 1 write 1
# _0111^_00_01_111
# state  fib0 read _ write _
# _0111_^00_01_111
# state  fib1 read 0 write 0
# _0111_0^0_01_111
# state  fib1 read 0 write 0
# _0111_00^_01_111
# state  fib1 read _ write _
# _0111_00_^01_111
# state  fib2 read 0 write 0
# _0111_00_0^1_111
# state  fib2 read 1 write 1
# _0111_00_01^_111
# state  fib2 read _ write _
# _0111_00_01_^111
# state  fib3 read 1 write 1
# _0111_00_01_1^11
# state  fib3 read 1 write 1
# _0111_00_01_11^1
# state  fib3 read 1 write 1
# _0111_00_01_111^1
# state  fib3 read _ write 1
# _0111_00_01_11^11
# state  fib4 read 1 write 1
# _0111_00_01_1^111
# state  fib4 read 1 write 1
# _0111_00_01_^1111
# state  fib4 read 1 write 1
# _0111_00_01^_1111
# state  fib4 read _ write _
# _0111_00_0^1_1111
# state  back0 read 1 write 1
# _0111_00_^01_1111
# state  back0 read 0 write 0
# _0111_00^_01_1111
# state  back0 read _ write _
# _0111_0^0_01_1111
# state  back1 read 0 write 0
# _0111_^00_01_1111
# state  back1 read 0 write 0
# _0111^_00_01_1111
# state  back1 read _ write _
# _011^1_00_01_1111
# state  back2 read 1 write 1
# _01^11_00_01_1111
# state  back2 read 1 write 1
# _0^111_00_01_1111
# state  back2 read 1 write 1
# _^0111_00_01_1111
# state  back2 read 0 write 0
# ^_0111_00_01_1111
# state  back2 read _ write _
# _^0111_00_01_1111
# state  checkn0 read 0 write 0
# _0^111_00_01_1111
# state  checkn0 read 1 write 1
# _01^11_00_01_1111
# state  sub0 read 1 write 1
# _011^1_00_01_1111
# state  sub0 read 1 write 1
# _0111^_00_01_1111
# state  sub0 read _ write _
# _011^0_00_01_1111
# state  sub1 read 1 write 0
# _01^10_00_01_1111
# state  sub2 read 1 write 1
# _0^110_00_01_1111
# state  sub2 read 1 write 1
# _^0110_00_01_1111
# state  sub2 read 0 write 0
# ^_0110_00_01_1111
# state  sub2 read _ write _
# _^0110_00_01_1111
# state  fib0 read 0 write 0
# _0^110_00_01_1111
# state  fib0 read 1 write 1
# _01^10_00_01_1111
# state  fib0 read 1 write 1
# _011^0_00_01_1111
# state  fib0 read 0 write 0
# _0110^_00_01_1111
# state  fib0 read _ write _
# _0110_^00_01_1111
# state  fib1 read 0 write 0
# _0110_0^0_01_1111
# state  fib1 read 0 write 0
# _0110_00^_01_1111
# state  fib1 read _ write _
# _0110_00_^01_1111
# state  fib2 read 0 write 0
# _0110_00_0^1_1111
# state  fib2 read 1 write 1
# _0110_00_01^_1111
# state  fib2 read _ write _
# _0110_00_01_^1111
# state  fib3 read 1 write 1
# _0110_00_01_1^111
# state  fib3 read 1 write 1
# _0110_00_01_11^11
# state  fib3 read 1 write 1
# _0110_00_01_111^1
# state  fib3 read 1 write 1
# _0110_00_01_1111^1
# state  fib3 read _ write 1
# _0110_00_01_111^11
# state  fib4 read 1 write 1
# _0110_00_01_11^111
# state  fib4 read 1 write 1
# _0110_00_01_1^1111
# state  fib4 read 1 write 1
# _0110_00_01_^11111
# state  fib4 read 1 write 1
# _0110_00_01^_11111
# state  fib4 read _ write _
# _0110_00_0^1_11111
# state  back0 read 1 write 1
# _0110_00_^01_11111
# state  back0 read 0 write 0
# _0110_00^_01_11111
# state  back0 read _ write _
# _0110_0^0_01_11111
# state  back1 read 0 write 0
# _0110_^00_01_11111
# state  back1 read 0 write 0
# _0110^_00_01_11111
# state  back1 read _ write _
# _011^0_00_01_11111
# state  back2 read 0 write 0
# _01^10_00_01_11111
# state  back2 read 1 write 1
# _0^110_00_01_11111
# state  back2 read 1 write 1
# _^0110_00_01_11111
# state  back2 read 0 write 0
# ^_0110_00_01_11111
# state  back2 read _ write _
# _^0110_00_01_11111
# state  checkn0 read 0 write 0
# _0^110_00_01_11111
# state  checkn0 read 1 write 1
# _01^10_00_01_11111
# state  sub0 read 1 write 1
# _011^0_00_01_11111
# state  sub0 read 0 write 0
# _0110^_00_01_11111
# state  sub0 read _ write _
# _011^1_00_01_11111
# state  sub1 read 0 write 1
# _01^01_00_01_11111
# state  sub1 read 1 write 0
# _0^101_00_01_11111
# state  sub2 read 1 write 1
# _^0101_00_01_11111
# state  sub2 read 0 write 0
# ^_0101_00_01_11111
# state  sub2 read _ write _
# _^0101_00_01_11111
# state  fib0 read 0 write 0
# _0^101_00_01_11111
# state  fib0 read 1 write 1
# _01^01_00_01_11111
# state  fib0 read 0 write 0
# _010^1_00_01_11111
# state  fib0 read 1 write 1
# _0101^_00_01_11111
# state  fib0 read _ write _
# _0101_^00_01_11111
# state  fib1 read 0 write 0
# _0101_0^0_01_11111
# state  fib1 read 0 write 0
# _0101_00^_01_11111
# state  fib1 read _ write _
# _0101_00_^01_11111
# state  fib2 read 0 write 0
# _0101_00_0^1_11111
# state  fib2 read 1 write 1
# _0101_00_01^_11111
# state  fib2 read _ write _
# _0101_00_01_^11111
# state  fib3 read 1 write 1
# _0101_00_01_1^1111
# state  fib3 read 1 write 1
# _0101_00_01_11^111
# state  fib3 read 1 write 1
# _0101_00_01_111^11
# state  fib3 read 1 write 1
# _0101_00_01_1111^1
# state  fib3 read 1 write 1
# _0101_00_01_11111^1
# state  fib3 read _ write 1
# _0101_00_01_1111^11
# state  fib4 read 1 write 1
# _0101_00_01_111^111
# state  fib4 read 1 write 1
# _0101_00_01_11^1111
# state  fib4 read 1 write 1
# _0101_00_01_1^11111
# state  fib4 read 1 write 1
# _0101_00_01_^111111
# state  fib4 read 1 write 1
# _0101_00_01^_111111
# state  fib4 read _ write _
# _0101_00_0^1_111111
# state  back0 read 1 write 1
# _0101_00_^01_111111
# state  back0 read 0 write 0
# _0101_00^_01_111111
# state  back0 read _ write _
# _0101_0^0_01_111111
# state  back1 read 0 write 0
# _0101_^00_01_111111
# state  back1 read 0 write 0
# _0101^_00_01_111111
# state  back1 read _ write _
# _010^1_00_01_111111
# state  back2 read 1 write 1
# _01^01_00_01_111111
# state  back2 read 0 write 0
# _0^101_00_01_111111
# state  back2 read 1 write 1
# _^0101_00_01_111111
# state  back2 read 0 write 0
# ^_0101_00_01_111111
# state  back2 read _ write _
# _^0101_00_01_111111
# state  checkn0 read 0 write 0
# _0^101_00_01_111111
# state  checkn0 read 1 write 1
# _01^01_00_01_111111
# state  sub0 read 0 write 0
# _010^1_00_01_111111
# state  sub0 read 1 write 1
# _0101^_00_01_111111
# state  sub0 read _ write _
# _010^0_00_01_111111
# state  sub1 read 1 write 0
# _01^00_00_01_111111
# state  sub2 read 0 write 0
# _0^100_00_01_111111
# state  sub2 read 1 write 1
# _^0100_00_01_111111
# state  sub2 read 0 write 0
# ^_0100_00_01_111111
# state  sub2 read _ write _
# _^0100_00_01_111111
# state  fib0 read 0 write 0
# _0^100_00_01_111111
# state  fib0 read 1 write 1
# _01^00_00_01_111111
# state  fib0 read 0 write 0
# _010^0_00_01_111111
# state  fib0 read 0 write 0
# _0100^_00_01_111111
# state  fib0 read _ write _
# _0100_^00_01_111111
# state  fib1 read 0 write 0
# _0100_0^0_01_111111
# state  fib1 read 0 write 0
# _0100_00^_01_111111
# state  fib1 read _ write _
# _0100_00_^01_111111
# state  fib2 read 0 write 0
# _0100_00_0^1_111111
# state  fib2 read 1 write 1
# _0100_00_01^_111111
# state  fib2 read _ write _
# _0100_00_01_^111111
# state  fib3 read 1 write 1
# _0100_00_01_1^11111
# state  fib3 read 1 write 1
# _0100_00_01_11^1111
# state  fib3 read 1 write 1
# _0100_00_01_111^111
# state  fib3 read 1 write 1
# _0100_00_01_1111^11
# state  fib3 read 1 write 1
# _0100_00_01_11111^1
# state  fib3 read 1 write 1
# _0100_00_01_111111^1
# state  fib3 read _ write 1
# _0100_00_01_11111^11
# state  fib4 read 1 write 1
# _0100_00_01_1111^111
# state  fib4 read 1 write 1
# _0100_00_01_111^1111
# state  fib4 read 1 write 1
# _0100_00_01_11^11111
# state  fib4 read 1 write 1
# _0100_00_01_1^111111
# state  fib4 read 1 write 1
# _0100_00_01_^1111111
# state  fib4 read 1 write 1
# _0100_00_01^_1111111
# state  fib4 read _ write _
# _0100_00_0^1_1111111
# state  back0 read 1 write 1
# _0100_00_^01_1111111
# state  back0 read 0 write 0
# _0100_00^_01_1111111
# state  back0 read _ write _
# _0100_0^0_01_1111111
# state  back1 read 0 write 0
# _0100_^00_01_1111111
# state  back1 read 0 write 0
# _0100^_00_01_1111111
# state  back1 read _ write _
# _010^0_00_01_1111111
# state  back2 read 0 write 0
# _01^00_00_01_1111111
# state  back2 read 0 write 0
# _0^100_00_01_1111111
# state  back2 read 1 write 1
# _^0100_00_01_1111111
# state  back2 read 0 write 0
# ^_0100_00_01_1111111
# state  back2 read _ write _
# _^0100_00_01_1111111
# state  checkn0 read 0 write 0
# _0^100_00_01_1111111
# state  checkn0 read 1 write 1
# _01^00_00_01_1111111
# state  sub0 read 0 write 0
# _010^0_00_01_1111111
# state  sub0 read 0 write 0
# _0100^_00_01_1111111
# state  sub0 read _ write _
# _010^1_00_01_1111111
# state  sub1 read 0 write 1
# _01^11_00_01_1111111
# state  sub1 read 0 write 1
# _0^011_00_01_1111111
# state  sub1 read 1 write 0
# _^0011_00_01_1111111
# state  sub2 read 0 write 0
# ^_0011_00_01_1111111
# state  sub2 read _ write _
# _^0011_00_01_1111111
# state  fib0 read 0 write 0
# _0^011_00_01_1111111
# state  fib0 read 0 write 0
# _00^11_00_01_1111111
# state  fib0 read 1 write 1
# _001^1_00_01_1111111
# state  fib0 read 1 write 1
# _0011^_00_01_1111111
# state  fib0 read _ write _
# _0011_^00_01_1111111
# state  fib1 read 0 write 0
# _0011_0^0_01_1111111
# state  fib1 read 0 write 0
# _0011_00^_01_1111111
# state  fib1 read _ write _
# _0011_00_^01_1111111
# state  fib2 read 0 write 0
# _0011_00_0^1_1111111
# state  fib2 read 1 write 1
# _0011_00_01^_1111111
# state  fib2 read _ write _
# _0011_00_01_^1111111
# state  fib3 read 1 write 1
# _0011_00_01_1^111111
# state  fib3 read 1 write 1
# _0011_00_01_11^11111
# state  fib3 read 1 write 1
# _0011_00_01_111^1111
# state  fib3 read 1 write 1
# _0011_00_01_1111^111
# state  fib3 read 1 write 1
# _0011_00_01_11111^11
# state  fib3 read 1 write 1
# _0011_00_01_111111^1
# state  fib3 read 1 write 1
# _0011_00_01_1111111^1
# state  fib3 read _ write 1
# _0011_00_01_111111^11
# state  fib4 read 1 write 1
# _0011_00_01_11111^111
# state  fib4 read 1 write 1
# _0011_00_01_1111^1111
# state  fib4 read 1 write 1
# _0011_00_01_111^11111
# state  fib4 read 1 write 1
# _0011_00_01_11^111111
# state  fib4 read 1 write 1
# _0011_00_01_1^1111111
# state  fib4 read 1 write 1
# _0011_00_01_^11111111
# state  fib4 read 1 write 1
# _0011_00_01^_11111111
# state  fib4 read _ write _
# _0011_00_0^1_11111111
# state  back0 read 1 write 1
# _0011_00_^01_11111111
# state  back0 read 0 write 0
# _0011_00^_01_11111111
# state  back0 read _ write _
# _0011_0^0_01_11111111
# state  back1 read 0 write 0
# _0011_^00_01_11111111
# state  back1 read 0 write 0
# _0011^_00_01_11111111
# state  back1 read _ write _
# _001^1_00_01_11111111
# state  back2 read 1 write 1
# _00^11_00_01_11111111
# state  back2 read 1 write 1
# _0^011_00_01_11111111
# state  back2 read 0 write 0
# _^0011_00_01_11111111
# state  back2 read 0 write 0
# ^_0011_00_01_11111111
# state  back2 read _ write _
# _^0011_00_01_11111111
# state  checkn0 read 0 write 0
# _0^011_00_01_11111111
# state  checkn0 read 0 write 0
# _00^11_00_01_11111111
# state  checkn0 read 1 write 1
# _001^1_00_01_11111111
# state  sub0 read 1 write 1
# _0011^_00_01_11111111
# state  sub0 read _ write _
# _001^0_00_01_11111111
# state  sub1 read 1 write 0
# _00^10_00_01_11111111
# state  sub2 read 1 write 1
# _0^010_00_01_11111111
# state  sub2 read 0 write 0
# _^0010_00_01_11111111
# state  sub2 read 0 write 0
# ^_0010_00_01_11111111
# state  sub2 read _ write _
# _^0010_00_01_11111111
# state  fib0 read 0 write 0
# _0^010_00_01_11111111
# state  fib0 read 0 write 0
# _00^10_00_01_11111111
# state  fib0 read 1 write 1
# _001^0_00_01_11111111
# state  fib0 read 0 write 0
# _0010^_00_01_11111111
# state  fib0 read _ write _
# _0010_^00_01_11111111
# state  fib1 read 0 write 0
# _0010_0^0_01_11111111
# state  fib1 read 0 write 0
# _0010_00^_01_11111111
# state  fib1 read _ write _
# _0010_00_^01_11111111
# state  fib2 read 0 write 0
# _0010_00_0^1_11111111
# state  fib2 read 1 write 1
# _0010_00_01^_11111111
# state  fib2 read _ write _
# _0010_00_01_^11111111
# state  fib3 read 1 write 1
# _0010_00_01_1^1111111
# state  fib3 read 1 write 1
# _0010_00_01_11^111111
# state  fib3 read 1 write 1
# _0010_00_01_111^11111
# state  fib3 read 1 write 1
# _0010_00_01_1111^1111
# state  fib3 read 1 write 1
# _0010_00_01_11111^111
# state  fib3 read 1 write 1
# _0010_00_01_111111^11
# state  fib3 read 1 write 1
# _0010_00_01_1111111^1
# state  fib3 read 1 write 1
# _0010_00_01_11111111^1
# state  fib3 read _ write 1
# _0010_00_01_1111111^11
# state  fib4 read 1 write 1
# _0010_00_01_111111^111
# state  fib4 read 1 write 1
# _0010_00_01_11111^1111
# state  fib4 read 1 write 1
# _0010_00_01_1111^11111
# state  fib4 read 1 write 1
# _0010_00_01_111^111111
# state  fib4 read 1 write 1
# _0010_00_01_11^1111111
# state  fib4 read 1 write 1
# _0010_00_01_1^11111111
# state  fib4 read 1 write 1
# _0010_00_01_^111111111
# state  fib4 read 1 write 1
# _0010_00_01^_111111111
# state  fib4 read _ write _
# _0010_00_0^1_111111111
# state  back0 read 1 write 1
# _0010_00_^01_111111111
# state  back0 read 0 write 0
# _0010_00^_01_111111111
# state  back0 read _ write _
# _0010_0^0_01_111111111
# state  back1 read 0 write 0
# _0010_^00_01_111111111
# state  back1 read 0 write 0
# _0010^_00_01_111111111
# state  back1 read _ write _
# _001^0_00_01_111111111
# state  back2 read 0 write 0
# _00^10_00_01_111111111
# state  back2 read 1 write 1
# _0^010_00_01_111111111
# state  back2 read 0 write 0
# _^0010_00_01_111111111
# state  back2 read 0 write 0
# ^_0010_00_01_111111111
# state  back2 read _ write _
# _^0010_00_01_111111111
# state  checkn0 read 0 write 0
# _0^010_00_01_111111111
# state  checkn0 read 0 write 0
# _00^10_00_01_111111111
# state  checkn0 read 1 write 1
# _001^0_00_01_111111111
# state  sub0 read 0 write 0
# _0010^_00_01_111111111
# state  sub0 read _ write _
# _001^1_00_01_111111111
# state  sub1 read 0 write 1
# _00^01_00_01_111111111
# state  sub1 read 1 write 0
# _0^001_00_01_111111111
# state  sub2 read 0 write 0
# _^0001_00_01_111111111
# state  sub2 read 0 write 0
# ^_0001_00_01_111111111
# state  sub2 read _ write _
# _^0001_00_01_111111111
# state  fib0 read 0 write 0
# _0^001_00_01_111111111
# state  fib0 read 0 write 0
# _00^01_00_01_111111111
# state  fib0 read 0 write 0
# _000^1_00_01_111111111
# state  fib0 read 1 write 1
# _0001^_00_01_111111111
# state  fib0 read _ write _
# _0001_^00_01_111111111
# state  fib1 read 0 write 0
# _0001_0^0_01_111111111
# state  fib1 read 0 write 0
# _0001_00^_01_111111111
# state  fib1 read _ write _
# _0001_00_^01_111111111
# state  fib2 read 0 write 0
# _0001_00_0^1_111111111
# state  fib2 read 1 write 1
# _0001_00_01^_111111111
# state  fib2 read _ write _
# _0001_00_01_^111111111
# state  fib3 read 1 write 1
# _0001_00_01_1^11111111
# state  fib3 read 1 write 1
# _0001_00_01_11^1111111
# state  fib3 read 1 write 1
# _0001_00_01_111^111111
# state  fib3 read 1 write 1
# _0001_00_01_1111^11111
# state  fib3 read 1 write 1
# _0001_00_01_11111^1111
# state  fib3 read 1 write 1
# _0001_00_01_111111^111
# state  fib3 read 1 write 1
# _0001_00_01_1111111^11
# state  fib3 read 1 write 1
# _0001_00_01_11111111^1
# state  fib3 read 1 write 1
# _0001_00_01_111111111^1
# state  fib3 read _ write 1
# _0001_00_01_11111111^11
# state  fib4 read 1 write 1
# _0001_00_01_1111111^111
# state  fib4 read 1 write 1
# _0001_00_01_111111^1111
# state  fib4 read 1 write 1
# _0001_00_01_11111^11111
# state  fib4 read 1 write 1
# _0001_00_01_1111^111111
# state  fib4 read 1 write 1
# _0001_00_01_111^1111111
# state  fib4 read 1 write 1
# _0001_00_01_11^11111111
# state  fib4 read 1 write 1
# _0001_00_01_1^111111111
# state  fib4 read 1 write 1
# _0001_00_01_^1111111111
# state  fib4 read 1 write 1
# _0001_00_01^_1111111111
# state  fib4 read _ write _
# _0001_00_0^1_1111111111
# state  back0 read 1 write 1
# _0001_00_^01_1111111111
# state  back0 read 0 write 0
# _0001_00^_01_1111111111
# state  back0 read _ write _
# _0001_0^0_01_1111111111
# state  back1 read 0 write 0
# _0001_^00_01_1111111111
# state  back1 read 0 write 0
# _0001^_00_01_1111111111
# state  back1 read _ write _
# _000^1_00_01_1111111111
# state  back2 read 1 write 1
# _00^01_00_01_1111111111
# state  back2 read 0 write 0
# _0^001_00_01_1111111111
# state  back2 read 0 write 0
# _^0001_00_01_1111111111
# state  back2 read 0 write 0
# ^_0001_00_01_1111111111
# state  back2 read _ write _
# _^0001_00_01_1111111111
# state  checkn0 read 0 write 0
# _0^001_00_01_1111111111
# state  checkn0 read 0 write 0
# _00^01_00_01_1111111111
# state  checkn0 read 0 write 0
# _000^1_00_01_1111111111
# state  checkn0 read 1 write 1
# _0001^_00_01_1111111111
# state  sub0 read _ write _
# _000^0_00_01_1111111111
# state  sub1 read 1 write 0
# _00^00_00_01_1111111111
# state  sub2 read 0 write 0
# _0^000_00_01_1111111111
# state  sub2 read 0 write 0
# _^0000_00_01_1111111111
# state  sub2 read 0 write 0
# ^_0000_00_01_1111111111
# state  sub2 read _ write _
# _^0000_00_01_1111111111
# state  fib0 read 0 write 0
# _0^000_00_01_1111111111
# state  fib0 read 0 write 0
# _00^00_00_01_1111111111
# state  fib0 read 0 write 0
# _000^0_00_01_1111111111
# state  fib0 read 0 write 0
# _0000^_00_01_1111111111
# state  fib0 read _ write _
# _0000_^00_01_1111111111
# state  fib1 read 0 write 0
# _0000_0^0_01_1111111111
# state  fib1 read 0 write 0
# _0000_00^_01_1111111111
# state  fib1 read _ write _
# _0000_00_^01_1111111111
# state  fib2 read 0 write 0
# _0000_00_0^1_1111111111
# state  fib2 read 1 write 1
# _0000_00_01^_1111111111
# state  fib2 read _ write _
# _0000_00_01_^1111111111
# state  fib3 read 1 write 1
# _0000_00_01_1^111111111
# state  fib3 read 1 write 1
# _0000_00_01_11^11111111
# state  fib3 read 1 write 1
# _0000_00_01_111^1111111
# state  fib3 read 1 write 1
# _0000_00_01_1111^111111
# state  fib3 read 1 write 1
# _0000_00_01_11111^11111
# state  fib3 read 1 write 1
# _0000_00_01_111111^1111
# state  fib3 read 1 write 1
# _0000_00_01_1111111^111
# state  fib3 read 1 write 1
# _0000_00_01_11111111^11
# state  fib3 read 1 write 1
# _0000_00_01_111111111^1
# state  fib3 read 1 write 1
# _0000_00_01_1111111111^1
# state  fib3 read _ write 1
# _0000_00_01_111111111^11
# state  fib4 read 1 write 1
# _0000_00_01_11111111^111
# state  fib4 read 1 write 1
# _0000_00_01_1111111^1111
# state  fib4 read 1 write 1
# _0000_00_01_111111^11111
# state  fib4 read 1 write 1
# _0000_00_01_11111^111111
# state  fib4 read 1 write 1
# _0000_00_01_1111^1111111
# state  fib4 read 1 write 1
# _0000_00_01_111^11111111
# state  fib4 read 1 write 1
# _0000_00_01_11^111111111
# state  fib4 read 1 write 1
# _0000_00_01_1^1111111111
# state  fib4 read 1 write 1
# _0000_00_01_^11111111111
# state  fib4 read 1 write 1
# _0000_00_01^_11111111111
# state  fib4 read _ write _
# _0000_00_0^1_11111111111
# state  back0 read 1 write 1
# _0000_00_^01_11111111111
# state  back0 read 0 write 0
# _0000_00^_01_11111111111
# state  back0 read _ write _
# _0000_0^0_01_11111111111
# state  back1 read 0 write 0
# _0000_^00_01_11111111111
# state  back1 read 0 write 0
# _0000^_00_01_11111111111
# state  back1 read _ write _
# _000^0_00_01_11111111111
# state  back2 read 0 write 0
# _00^00_00_01_11111111111
# state  back2 read 0 write 0
# _0^000_00_01_11111111111
# state  back2 read 0 write 0
# _^0000_00_01_11111111111
# state  back2 read 0 write 0
# ^_0000_00_01_11111111111
# state  back2 read _ write _
# _^0000_00_01_11111111111
# state  checkn0 read 0 write 0
# _0^000_00_01_11111111111
# state  checkn0 read 0 write 0
# _00^00_00_01_11111111111
# state  checkn0 read 0 write 0
# _000^0_00_01_11111111111
# state  checkn0 read 0 write 0
# _0000^_00_01_11111111111
# state  checkn0 read _ write _
# _0000_^00_01_11111111111
# state  clean read 0 write 0
# _0000^_00_01_11111111111
# state  HALT

# %%
len("11111111111")
# Out:
# 11

# %%
add = [
    "START: 01Raddnc1 11Raddnc2 __L0nc",
    "addnc1: 00R0nc 11R1nc",
    "addnc2: 00RSTART 11RSTART",
    
    "addc0: 01Raddc1 11Raddc2 __L1nc",
    "addc1: 00R1nc 11R0c",
    "addc2: 00Raddc0 11Raddc0",
    
    "0nc: 00R0nc 11R0nc __R0nc1",
#     "0nc1: 01R0nc2 11R0nc3 __Lwrite0nc",
    "0nc1: 01R0nc2 11R0nc3 __Rfinish",
    "0nc2: 00Rwrite0nc 11Rwrite1nc",
    "0nc3: 00R0nc1 11R0nc1",
    
    "1nc: 00R1nc 11R1nc __R1nc1",
    "1nc1: 01R1nc2 11R1nc3 __Lwrite1nc",
#     "1nc1: 01R1nc2 11R1nc3 __RHALT",
    "1nc2: 00Rwrite1nc 11Rwrite0c",
    "1nc3: 00R1nc1 11R1nc1",
    
    "0c: 00R0c 11R0c __R0c1",
#     "0c1: 01R0c2 11R0c3 __Lwrite0c",
    "0c1: 01R0c2 11R0c3 __Rfinish",
    "0c2: 00Rwrite0c 11Rwrite1c",
    "0c3: 00R0c1 11R0c1",
    
    "write0nc: 00Rwrite0nc 11Rwrite0nc __Rwrite0nc1",
    "write0nc1: 00Rwrite0nc1 11Rwrite0nc1 _0Rwrite0nc2",
    "write0nc2: 00Rwrite0nc1 11Rwrite0nc1 _0Lgobacknc",
#     "write0nc1: _0Rwrite0nc2",
#     "write0nc2: _0Lgobacknc",
    
    "write1nc: 00Rwrite1nc 11Rwrite1nc __Rwrite1nc1",
    "write1nc1: 00Rwrite1nc1 11Rwrite1nc1 _0Rwrite1nc2",
    "write1nc2: 00Rwrite1nc1 11Rwrite1nc1 _1Lgobacknc",
#     "write1nc1: _0Rwrite1nc2",
#     "write1nc2: _1Lgobacknc",
    
    "write0c: 00Rwrite0c 11Rwrite0c __Rwrite0c1",
    "write0c1: 00Rwrite0c1 11Rwrite0c1 _0Rwrite0c2",
    "write0c2: 00Rwrite0c1 11Rwrite0c1 _0Lgobackc",
#     "write0c1: _0Rwrite0c2",
#     "write0c2: _0Lgobackc",
    
    "write1c: 00Rwrite1c 11Rwrite1c __Rwrite1c1",
    "write1c1: 00Rwrite1c1 11Rwrite1c1 _0Rwrite1c2",
    "write1c2: 00Rwrite1c1 11Rwrite1c1 _1Lgobackc",
#     "write1c1: _0Rwrite0c2",
#     "write1c2: _1Lgobackc",
    
    "gobacknc: 00Lgobacknc 11Lgobacknc __Lgobacknc1",
    "gobacknc1: 00Lgobacknc1 11Lgobacknc1 __Lgobacknc2",
    "gobacknc2: 00Lgobacknc2 11Lgobacknc2 __RSTART",
#     "gobacknc3: 00Lgobacknc3 11Lgobacknc3 __LSTART",
    
    "gobackc: 00Lgobackc 11Lgobackc __Lgobackc1",
    "gobackc1: 00Lgobackc1 11Lgobackc1 __Lgobackc2",
    "gobackc2: 00Lgobackc2 11Lgobackc2 __Raddc0",
#     "gobackc3: 00Lgobackc3 11Lgobackc3 __Laddc0",
    "finish: 00Lfinish 11Lfinish __Lfinish1",
    "finish1: 00Lfinish1 11Lfinish1 __Lfinish2",
    "finish2: 00Lfinish2 11Lfinish2 __RHALT",
]

add_mach = parse(add)

# %%
run(add_mach, list("0101_0101"), debug=True)
pass
# Out:
# ^1101_0101
# state  START read 0 write 1
# 1^101_0101
# state  addnc1 read 1 write 1
# 11^01_0101
# state  1nc read 0 write 0
# 110^1_0101
# state  1nc read 1 write 1
# 1101^_0101
# state  1nc read _ write _
# 1101_^1101
# state  1nc1 read 0 write 1
# 1101_1^101
# state  1nc2 read 1 write 1
# 1101_11^01
# state  write0c read 0 write 0
# 1101_110^1
# state  write0c read 1 write 1
# 1101_1101^_
# state  write0c read _ write _
# 1101_1101_^0
# state  write0c1 read _ write 0
# 1101_1101_0^0
# state  write0c2 read _ write 0
# 1101_1101_^00
# state  gobackc read 0 write 0
# 1101_1101^_00
# state  gobackc read _ write _
# 1101_110^1_00
# state  gobackc1 read 1 write 1
# 1101_11^01_00
# state  gobackc1 read 0 write 0
# 1101_1^101_00
# state  gobackc1 read 1 write 1
# 1101_^1101_00
# state  gobackc1 read 1 write 1
# 1101^_1101_00
# state  gobackc1 read _ write _
# 110^1_1101_00
# state  gobackc2 read 1 write 1
# 11^01_1101_00
# state  gobackc2 read 0 write 0
# 1^101_1101_00
# state  gobackc2 read 1 write 1
# ^1101_1101_00
# state  gobackc2 read 1 write 1
# ^_1101_1101_00
# state  gobackc2 read _ write _
# _^1101_1101_00
# state  addc0 read 1 write 1
# _1^101_1101_00
# state  addc2 read 1 write 1
# _11^11_1101_00
# state  addc0 read 0 write 1
# _111^1_1101_00
# state  addc1 read 1 write 1
# _1111^_1101_00
# state  0c read _ write _
# _1111_^1101_00
# state  0c1 read 1 write 1
# _1111_1^101_00
# state  0c3 read 1 write 1
# _1111_11^11_00
# state  0c1 read 0 write 1
# _1111_111^1_00
# state  0c2 read 1 write 1
# _1111_1111^_00
# state  write1c read _ write _
# _1111_1111_^00
# state  write1c1 read 0 write 0
# _1111_1111_0^0
# state  write1c1 read 0 write 0
# _1111_1111_00^0
# state  write1c1 read _ write 0
# _1111_1111_000^1
# state  write1c2 read _ write 1
# _1111_1111_00^01
# state  gobackc read 0 write 0
# _1111_1111_0^001
# state  gobackc read 0 write 0
# _1111_1111_^0001
# state  gobackc read 0 write 0
# _1111_1111^_0001
# state  gobackc read _ write _
# _1111_111^1_0001
# state  gobackc1 read 1 write 1
# _1111_11^11_0001
# state  gobackc1 read 1 write 1
# _1111_1^111_0001
# state  gobackc1 read 1 write 1
# _1111_^1111_0001
# state  gobackc1 read 1 write 1
# _1111^_1111_0001
# state  gobackc1 read _ write _
# _111^1_1111_0001
# state  gobackc2 read 1 write 1
# _11^11_1111_0001
# state  gobackc2 read 1 write 1
# _1^111_1111_0001
# state  gobackc2 read 1 write 1
# _^1111_1111_0001
# state  gobackc2 read 1 write 1
# ^_1111_1111_0001
# state  gobackc2 read _ write _
# _^1111_1111_0001
# state  addc0 read 1 write 1
# _1^111_1111_0001
# state  addc2 read 1 write 1
# _11^11_1111_0001
# state  addc0 read 1 write 1
# _111^1_1111_0001
# state  addc2 read 1 write 1
# _1111^_1111_0001
# state  addc0 read _ write _
# _111^1_1111_0001
# state  1nc read 1 write 1
# _1111^_1111_0001
# state  1nc read _ write _
# _1111_^1111_0001
# state  1nc1 read 1 write 1
# _1111_1^111_0001
# state  1nc3 read 1 write 1
# _1111_11^11_0001
# state  1nc1 read 1 write 1
# _1111_111^1_0001
# state  1nc3 read 1 write 1
# _1111_1111^_0001
# state  1nc1 read _ write _
# _1111_111^1_0001
# state  write1nc read 1 write 1
# _1111_1111^_0001
# state  write1nc read _ write _
# _1111_1111_^0001
# state  write1nc1 read 0 write 0
# _1111_1111_0^001
# state  write1nc1 read 0 write 0
# _1111_1111_00^01
# state  write1nc1 read 0 write 0
# _1111_1111_000^1
# state  write1nc1 read 1 write 1
# _1111_1111_0001^0
# state  write1nc1 read _ write 0
# _1111_1111_00010^1
# state  write1nc2 read _ write 1
# _1111_1111_0001^01
# state  gobacknc read 0 write 0
# _1111_1111_000^101
# state  gobacknc read 1 write 1
# _1111_1111_00^0101
# state  gobacknc read 0 write 0
# _1111_1111_0^00101
# state  gobacknc read 0 write 0
# _1111_1111_^000101
# state  gobacknc read 0 write 0
# _1111_1111^_000101
# state  gobacknc read _ write _
# _1111_111^1_000101
# state  gobacknc1 read 1 write 1
# _1111_11^11_000101
# state  gobacknc1 read 1 write 1
# _1111_1^111_000101
# state  gobacknc1 read 1 write 1
# _1111_^1111_000101
# state  gobacknc1 read 1 write 1
# _1111^_1111_000101
# state  gobacknc1 read _ write _
# _111^1_1111_000101
# state  gobacknc2 read 1 write 1
# _11^11_1111_000101
# state  gobacknc2 read 1 write 1
# _1^111_1111_000101
# state  gobacknc2 read 1 write 1
# _^1111_1111_000101
# state  gobacknc2 read 1 write 1
# ^_1111_1111_000101
# state  gobacknc2 read _ write _
# _^1111_1111_000101
# state  START read 1 write 1
# _1^111_1111_000101
# state  addnc2 read 1 write 1
# _11^11_1111_000101
# state  START read 1 write 1
# _111^1_1111_000101
# state  addnc2 read 1 write 1
# _1111^_1111_000101
# state  START read _ write _
# _111^1_1111_000101
# state  0nc read 1 write 1
# _1111^_1111_000101
# state  0nc read _ write _
# _1111_^1111_000101
# state  0nc1 read 1 write 1
# _1111_1^111_000101
# state  0nc3 read 1 write 1
# _1111_11^11_000101
# state  0nc1 read 1 write 1
# _1111_111^1_000101
# state  0nc3 read 1 write 1
# _1111_1111^_000101
# state  0nc1 read _ write _
# _1111_1111_^000101
# state  finish read 0 write 0
# _1111_1111^_000101
# state  finish read _ write _
# _1111_111^1_000101
# state  finish1 read 1 write 1
# _1111_11^11_000101
# state  finish1 read 1 write 1
# _1111_1^111_000101
# state  finish1 read 1 write 1
# _1111_^1111_000101
# state  finish1 read 1 write 1
# _1111^_1111_000101
# state  finish1 read _ write _
# _111^1_1111_000101
# state  finish2 read 1 write 1
# _11^11_1111_000101
# state  finish2 read 1 write 1
# _1^111_1111_000101
# state  finish2 read 1 write 1
# _^1111_1111_000101
# state  finish2 read 1 write 1
# ^_1111_1111_000101
# state  finish2 read _ write _
# _^1111_1111_000101
# state  HALT

# %%
def test_add(i, j):
    t = ("0".join(bin((max(i,j)))[2:]) + "0_" + "0".join(bin(min(i,j))[2:]) + "0")[::-1]
    out = run(parse(add), list(t), debug=False)
    num = int(("".join(out)).split("_")[-1][1::2][::-1], 2)
    print("Good" if i + j == num else "BADBADBAD", i, j, num)
    if i+j != num:
        print(t)
        print("".join(out))
        return False
    return True


from random import randint

for i in range(10000):
    if test_add(randint(0,1<<79), randint(0,1<<86)) == False:
        break
# Out:
# Good 398639272747904432063112 33481868637943622633499906 33880507910691527065563018
# Good 185668612028229300075268 66030355808774178821297394 66216024420802408121372662
# Good 75868150424376080316478 1216447424709474680941258 1292315575133850761257736
# Good 597797519164923956601781 10297686240284668011288774 10895483759449591967890555
# Good 483433273773209880856196 69361376427839850321612246 69844809701613060202468442
# Good 587016352849940821206856 57364397987832025069114941 57951414340681965890321797
# Good 483641419623901983935160 49160395327896396991786534 49644036747520298975721694
# Good 509430464241254150187021 13424412514487821609281303 13933842978729075759468324
# Good 505132595126688973281595 65620329427415876808375252 66125462022542565781656847
# Good 205640075330251366026333 46852329555232584093106049 47057969630562835459132382
# Good 538507150008989990160685 44646708409693989779476816 45185215559702979769637501
# Good 249864092060863846209320 31670864098847966493099999 31920728190908830339309319
# Good 95157978180248420022979 28835230546940165511447589 28930388525120413931470568
# Good 271114025160824165243186 58163545835698117462014588 58434659860858941627257774
# Good 361216031619847642003003 49822998341428990135526712 50184214373048837777529715
# Good 573562024302143018864755 48779052316301756495890169 49352614340603899514754924
# Good 10990890583763057434111 12449642135770746373684287 12460633026354509431118398
# Good 117749884296114191587186 22853519927852802227768393 22971269812148916419355579
# Good 125133666088404073245026 16924347132391757142857917 17049480798480161216102943
# Good 409006828441388479206427 67735960881733986077369947 68144967710175374556576374
# Good 452936232470062842419903 31132980604461204577701492 31585916836931267420121395
# Good 560644219212351404532918 2328030372086082839563750 2888674591298434244096668
# Good 54695033966729986106161 29296051317322498584708050 29350746351289228570814211
# Good 240162448520994484741639 10285110981013760988978027 10525273429534755473719666
# Good 111900515531108710798610 32311667676143167555583265 32423568191674276266381875
# Good 524224151823761826060722 71811570800823053705904500 72335794952646815531965222
# Good 498027194666547677471369 5044058671278456975752097 5542085865945004653223466
# Good 505830301537766786627253 1497310800979477504163744 2003141102517244290790997
# Good 477341059031435527428238 15661832795253863585492232 16139173854285299112920470
# Good 120154767812693709934892 9059575097360030506137115 9179729865172724216072007
# Good 350037825334433266357855 20439132251905241499182198 20789170077239674765540053
# Good 57524211392315698462009 30869379707741840333747334 30926903919134156032209343
# Good 373742288325548317243505 43005226266775590983503259 43378968555101139300746764
# Good 440054515476300446119574 67693938041811920032680064 68133992557288220478799638
# Good 212083248457042669608210 51045525089877632923721993 51257608338334675593330203
# Good 588722127617054793089154 44525323994449837103126848 45114046122066891896216002
# Good 344661062829592722544364 34121283766158074658840926 34465944828987667381385290
# Good 442526243767539139228438 28200257651972282354673606 28642783895739821493902044
# Good 51490404625711948946030 24759849656653507000020550 24811340061279218948966580
# Good 516799280899634295981394 33674506929893142026036261 34191306210792776322017655
# Good 316040103400493102546682 23109792514949963169705694 23425832618350456272252376
# Good 99761631862496956844279 32921842037427549802818713 33021603669290046759662992
# Good 212699821656288085874488 46252794477456269811377967 46465494299112557897252455
# Good 378499762909191912939021 44115037700238101513469874 44493537463147293426408895
# Good 129789848411214963886858 21864873819475904585828733 21994663667887119549715591
# Good 45562011033841508820497 41429883480881948649394341 41475445491915790158214838
# Good 352716085118995262237113 7115012149935265985174417 7467728235054261247411530
# Good 320512533739295605641454 61453879512826390986755626 61774392046565686592397080
# Good 356402290124939270206245 36392109063710878044148412 36748511353835817314354657
# Good 124277573943394714243397 50275041010856244030128948 50399318584799638744372345
# Good 507889253768562830300958 27732504918361186058204626 28240394172129748888505584
# Good 573663244448848908992661 8052079960413744824366099 8625743204862593733358760
# Good 53906026009504068627791 15076269600421105893854658 15130175626430609962482449
# Good 492517474201076497031605 25020098108851414177614200 25512615583052490674645805
# Good 108024142400877993647713 11371619721634742407205625 11479643864035620400853338
# Good 405727788002766560852090 14625939308948972704150391 15031667096951739265002481
# Good 101707238154711551569816 6095637521883070674662537 6197344760037782226232353
# Good 210585926041382591691024 44521800499777054862903131 44732386425818437454594155
# Good 314356182979509796258342 26315725710512390440948726 26630081893491900237207068
# Good 177022207230018695080589 16487540557906069584784296 16664562765136088279864885
# Good 557807279025120649338341 14804314170031600384237324 15362121449056721033575665
# Good 444223629887803669563143 56991211757926004657535417 57435435387813808327098560
# Good 256338379189485390841977 20702306976132289221207178 20958645355321774612049155
# Good 293699960894578911837387 42714977586759356475262697 43008677547653935387100084
# Good 406654547689481694216118 19458843608336558182815754 19865498156026039877031872
# Good 171763941126307052241392 71321528037752843018998630 71493291978879150071240022
# Good 438644698672196332566224 31246724021627462745813634 31685368720299659078379858
# Good 405894105726793357977244 60993241464629928604370615 61399135570356721962347859
# Good 119609239468754360638751 38613365031294128659165591 38732974270762883019804342
# Good 182641947941457621857645 10695246453029278262118478 10877888400970735883976123
# Good 139151898041907573227847 29217998871609155109503979 29357150769651062682731826
# Good 266432207190186376119829 65348911217985105439754812 65615343425175291815874641
# Good 253682282850384960712609 35276363677961401151077107 35530045960811786111789716
# Good 533810843226985051869027 67253329194000767386577820 67787140037227752438446847
# Good 449074968750686578399634 69645775343161277889621404 70094850311911964468021038
# Good 576646764492595863523257 2308299351228026365595464 2884946115720622229118721
# Good 162310163187755170621790 64965585842556933777034421 65127896005744688947656211
# Good 333585453659301907566091 51479780890275051823719613 51813366343934353731285704
# Good 404369832362072878895707 7367904217324250307361841 7772274049686323186257548
# Good 90296448406998253965463 10828805335231196424661362 10919101783638194678626825
# Good 136363811580872590046231 28639515466326083582915942 28775879277906956172962173
# Good 483427077764580967372354 61984213559472126095680006 62467640637236707063052360
# Good 241682019444246702818147 14556337107535234440640204 14798019126979481143458351
# Good 23343581562372818368506 45673993046062442719097104 45697336627624815537465610
# Good 338734042246528990830036 30812859427757163167917298 31151593470003692158747334
# Good 570898249995732201044590 11657403312358467437952478 12228301562354199638997068
# Good 167706794553420344088046 67388825551654776353009743 67556532346208196697097789
# Good 16251972582525572910150 22759378167249344254957654 22775630139831869827867804
# Good 458216886926016426525691 61350469095568857684021535 61808685982494874110547226
# Good 465924248619155517005213 1987790006859825099894646 2453714255478980616899859
# Good 491128547728857924728828 28562364963393432739798191 29053493511122290664527019
# Good 91532263456891128734186 17800641126496234733580840 17892173389953125862315026
# Good 297172179489864750629338 39788539683272080902686863 40085711862761945653316201
# Good 129300004646678176783472 73096113509711329626806172 73225413514358007803589644
# Good 41631521837186490360093 51970739094610849318447760 52012370616448035808807853
# Good 524016056860071610666084 22273396551424077634770871 22797412608284149245436955
# Good 57070055347915189032093 40444860506434922625450031 40501930561782837814482124
# Good 93808812493554021741967 5972174953943125390322455 6065983766436679412064422
# Good 96274639795168891596971 70942309410482070345075350 71038584050277239236672321
# Good 84506030102652116189721 70783910962399605825373148 70868416992502257941562869

# %%
randint(0, 1777)
# Out:
# 1299
